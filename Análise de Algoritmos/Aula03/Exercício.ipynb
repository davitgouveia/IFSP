# %% [markdown]
# **<p>Aula03 - Exercícios de fixação</p>**
# **<p>Davi Trost Gouveia - PC3010741</p>**

# %% [markdown]
# # Exercício 1 #

# %% [markdown]
# ![](ex1.png)

# %% [markdown]
# ## for Loop ##
#
# **Inicialização:**
#
# > - Atribuição: (int i=0;) = 1
# > - Comparação: (i<n;) = 1
#
# **Execução:**
#
# > - Comparação: (i<n;) = n
# > - Incremento : (i++) = n
#
# **Execução do comando:**
#
# > - Execução do print: n
#
# Primeiro loop tem um total de: 3n + 2 instruções
#
# Como os dois loops não estão aninhados, basta multiplicar a contagem por 2.
#
# Portanto, o algoritmo possuí **6n + 4** instruções.

# %% [markdown]
# ## Plotando o gráfico ##
# Valor de N x Contagem de instruções

# %%
import matplotlib.pyplot as plt

# %%
def countInstructions(n):
    instructionsTotal = 6*n + 4
    return instructionsTotal

# %%
n_count = range(1,50)

instructions_count = [countInstructions(n) for n in n_count]

plt.plot(n_count, instructions_count)
plt.xlabel('Valor de N')
plt.ylabel('Contagem de instruções')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Exercício 2 #

# %% [markdown]
# ![](ex2a.png)

# %% [markdown]
# **Inicialização:**
#
# > - Atribuição: (int i=0;) = 1
# > - Comparação: (i<n/2;) = 1
#
# **Execução:**
#
# > - Comparação: (i<n;) = n/2
# > - Incremento : (i++) = n/2
#
# **Execução do comando:**
#
# > - Execução do print: n/2
#
# O algoritmo possuí 3n/2 + 2 instruções.

# %% [markdown]
# ## Plotando o gráfico ##
# Valor de N x Contagem de instruções

# %%
def countInstructions(n):
    instructionsTotal = 3*n/2 + 2
    return instructionsTotal

# %%
n_count = range(1,50)

instructions_count = [countInstructions(n) for n in n_count]

plt.plot(n_count, instructions_count)
plt.xlabel('Valor de N')
plt.ylabel('Contagem de instruções')
plt.show()
